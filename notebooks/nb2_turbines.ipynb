# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ass1.loaders import load_tmy
from ass1.modeling.location import WindResourceData

df = load_tmy()
loc = WindResourceData(df["datetime"], df["WS50M"], df["WD50M"])
resource = loc.create_weibull_wind_resource()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ass1.loaders import load_tmy
#       2 from ass1.modeling.location import WindResourceData
#       3
#       4 df = load_tmy()
#
# File C:\Uni\14. Semester\Kurse\Design of Renewable Energy Production Systems\Python\ENN554-assignment1\ass1\__init__.py:1
# ----> 1 from ass1 import config  # noqa: F401
#
# File C:\Uni\14. Semester\Kurse\Design of Renewable Energy Production Systems\Python\ENN554-assignment1\ass1\config.py:3
#       1 from pathlib import Path
# ----> 3 from dotenv import load_dotenv
#       4 from loguru import logger
#       6 # Load environment variables from .env file if it exists
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
from ass1.loaders import load_nrel_6MW, load_nrel_8MW, load_nrel_10MW, load_dtu_10MW
import numpy as np

turb6 = load_nrel_6MW()
turb8 = load_nrel_8MW()
turb10 = load_nrel_10MW()
turbdtu = load_dtu_10MW()

# %%
turb6.plot_power_curve()

# %%
resource.plot_power_distribution(turb6).show()
resource.plot_power_distribution(turb8).show()
resource.plot_power_distribution(turb10).show()
resource.plot_power_distribution(turbdtu).show()

# %%
resource.plot_cumulative_distributions([turb6, turb8, turb10, turbdtu])
# Need to fix the Power CDF
