# %%
from ass1.loaders import load_demand
# Out:
# 2026-04-20 11:31:55.059 | INFO     | ass1.config:<module>:11 - PROJ_ROOT path is: /workspaces/Uni/ENN554-REP/ass1

# %%
from ass1.loaders import load_site_year


df = load_site_year()
# Out:
# 2026-04-22 01:41:46.856 | INFO     | ass1.config:<module>:11 - PROJ_ROOT path is: /workspaces/Uni/ENN554-REP/ass1

# %%
print(df)
# Out:
#                     Time  Load [MW]  WS50M  WD50M
# 0    2023-01-01 00:00:00  21.097694   5.34   71.6
# 1    2023-01-01 01:00:00  17.718767   5.65   67.2
# 2    2023-01-01 02:00:00  15.150232   5.81   62.6
# 3    2023-01-01 03:00:00  11.991072   5.85   58.7
# 4    2023-01-01 04:00:00  10.644996   5.82   55.8
# ...                  ...        ...    ...    ...
# 8755 2023-12-31 19:00:00  51.411895   2.41  108.1
# 8756 2023-12-31 20:00:00   45.38202   2.64   90.9
# 8757 2023-12-31 21:00:00  40.602073   3.07   77.4
# 8758 2023-12-31 22:00:00  35.671037   3.69   67.0
# 8759 2023-12-31 23:00:00  32.484406   4.34   60.9
#
# [8760 rows x 4 columns]
