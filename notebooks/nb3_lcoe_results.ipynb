# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ass1.modeling.loaders import load_tmy
from ass1.modeling.location import WindResourceData

df = load_tmy()
loc = WindResourceData(df["datetime"], df["WS50M"], df["WD50M"])
resource = loc.create_weibull_wind_resource()
# Out:
# 2026-04-06 09:26:45.566 | INFO     | ass1.config:<module>:11 - PROJ_ROOT path is: /workspaces/Uni/ENN554-REP/ass1

# %%
from ass1.modeling.financial import FinancialModel
import pandas as pd

from ass1.modeling.loaders import load_nrel_6MW, load_nrel_8MW, load_nrel_10MW, load_dtu_10MW

fcr = 0.05

turbine_options = [
    load_nrel_6MW(), load_nrel_8MW(),load_nrel_10MW(),
    load_dtu_10MW()
    ]

finance = FinancialModel(fcr=fcr)

results = {}
for turbine in turbine_options:
    aep = resource.aep(turbine)
    c_rotor, c_tower, c_other = finance.cost_turbine_components(turbine)
    lcoe = finance.lcoe(turbine, aep)

    results[turbine.name] = {
        "Anunual Energy Production (GWh)": aep * 1e-6,
        "Rotor + Tower cost (AUD)": c_rotor+c_tower,
        "Other costs (AUD)": c_other,
        "TCC (AUD)": c_rotor + c_tower +c_other,
        "Levelised Cost Energy (AUD/MWh)": lcoe * 1e3
    }

df = pd.DataFrame(results).T
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 17
#      15 results = {}
#      16 for turbine in turbine_options:
# ---> 17     aep = resource.aep(turbine)
#      18     c_rotor, c_tower, c_other = finance.cost_turbine_components(turbine)
#      19     lcoe = finance.lcoe(turbine, aep)
#
# File /workspaces/Uni/ENN554-REP/ass1/ass1/modeling/location.py:31, in WindResourceModel.aep(self, turbine, n_points)
#      28 pdf_val = self.pdf(ws_rng)
#      30 # return 8760 * (power * pdf_val).sum()
# ---> 31 aep, err = 8760 * quad(
#      32     lambda x: turbine.power_at(x) * self.pdf(x), 0, turbine.cut_out_wind_speed
#      33 )
#      35 if err is not None:
#      36     raise err
#
# File ~/.cache/pypoetry/virtualenvs/ass1-MDXb4IMp-py3.12/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:479, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     476     return retval
#     478 if weight is None:
# --> 479     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     480                    points)
#     481 else:
#     482     if points is not None:
#
# File ~/.cache/pypoetry/virtualenvs/ass1-MDXb4IMp-py3.12/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:626, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     624 if points is None:
#     625     if infbounds == 0:
# --> 626         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     627     else:
#     628         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     629                                 epsabs, epsrel, limit)
#
# File /workspaces/Uni/ENN554-REP/ass1/ass1/modeling/location.py:32, in WindResourceModel.aep.<locals>.<lambda>(x)
#      28 pdf_val = self.pdf(ws_rng)
#      30 # return 8760 * (power * pdf_val).sum()
#      31 aep, err = 8760 * quad(
# ---> 32     lambda x: turbine.power_at(x) * self.pdf(x), 0, turbine.cut_out_wind_speed
#      33 )
#      35 if err is not None:
#      36     raise err
#
# File /workspaces/Uni/ENN554-REP/ass1/ass1/modeling/turbine.py:103, in WindTurbine.power_at(self, turbine_ws, ws_50)
#      94 power = np.interp(
#      95     turbine_ws,
#      96     curve["wind_speed"].to_numpy(),
#    (...)     99     right=0.0,  # above cut-out → 0
#     100 )
#     102 # Zero out anything outside the operational envelope
# --> 103 power[(turbine_ws < self.cut_in_wind_speed) | (turbine_ws > self.cut_out_wind_speed)] = 0.0
#     105 return turbine_ws, power
#
# TypeError: 'numpy.float64' object does not support item assignment

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
